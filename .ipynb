# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
# Your code here - remember to use markdown cells for comments as well!
import pandas as pd
import glob
file_list = glob.glob('zippedData/*.gz*')
file_list
# Out:
# ['zippedData\\bom.movie_gross.csv.gz',
#  'zippedData\\imdb.name.basics.csv.gz',
#  'zippedData\\imdb.title.akas.csv.gz',
#  'zippedData\\imdb.title.basics.csv.gz',
#  'zippedData\\imdb.title.crew.csv.gz',
#  'zippedData\\imdb.title.principals.csv.gz',
#  'zippedData\\imdb.title.ratings.csv.gz',
#  'zippedData\\rt.movie_info.tsv.gz',
#  'zippedData\\rt.reviews.tsv.gz',
#  'zippedData\\tmdb.movies.csv.gz',
#  'zippedData\\tn.movie_budgets.csv.gz']

# %%
import os
os.listdir('zippedData/')
# Out:
# ['.ipynb_checkpoints',
#  'bom.movie_gross.csv.gz',
#  'imdb.name.basics.csv.gz',
#  'imdb.title.akas.csv.gz',
#  'imdb.title.basics.csv.gz',
#  'imdb.title.crew.csv.gz',
#  'imdb.title.principals.csv.gz',
#  'imdb.title.ratings.csv.gz',
#  'rt.movie_info.tsv.gz',
#  'rt.reviews.tsv.gz',
#  'tmdb.movies.csv.gz',
#  'tn.movie_budgets.csv.gz']

# %%
file_list[0].split('/')[-1].replace('.csv.gz', '')
# Out:
# 'zippedData\\bom.movie_gross'

# %%
TABLES = {}
for file in file_list:
    try:
        df = pd.read_csv(file)
    except:
        df = None
        print(f"{file} didn't load.")
    key = file.split('/')[-1].replace('.csv.gz', '')
    TABLES[key] = df
# Out:
# zippedData\rt.movie_info.tsv.gz didn't load.
# zippedData\rt.reviews.tsv.gz didn't load.

# %%
TABLES.keys()
# Out:
# dict_keys(['zippedData\\bom.movie_gross', 'zippedData\\imdb.name.basics', 'zippedData\\imdb.title.akas', 'zippedData\\imdb.title.basics', 'zippedData\\imdb.title.crew', 'zippedData\\imdb.title.principals', 'zippedData\\imdb.title.ratings', 'zippedData\\rt.movie_info.tsv.gz', 'zippedData\\rt.reviews.tsv.gz', 'zippedData\\tmdb.movies', 'zippedData\\tn.movie_budgets'])

# %%
import numpy as np
movie_gross = TABLES['zippedData\\bom.movie_gross']
name_basics = TABLES['zippedData\\imdb.name.basics']
title_aka = TABLES['zippedData\\imdb.title.akas']
title_basics = TABLES['zippedData\\imdb.title.basics']
title_crew = TABLES['zippedData\\imdb.title.crew']
title_principals = TABLES['zippedData\\imdb.title.principals']
title_ratings = TABLES['zippedData\\imdb.title.ratings']
movie_info = TABLES['zippedData\\rt.movie_info.tsv.gz']
reviews = TABLES['zippedData\\rt.reviews.tsv.gz']
tmdb = TABLES['zippedData\\tmdb.movies']
movie_budgets = TABLES['zippedData\\tn.movie_budgets']

# %%
title_basics = title_basics.dropna()
title_basics
# Out:
#            tconst                                      primary_title  \
# 0       tt0063540                                          Sunghursh
# 1       tt0066787                    One Day Before the Rainy Season
# 2       tt0069049                         The Other Side of the Wind
# 4       tt0100275                           The Wandering Soap Opera
# 5       tt0111414                                        A Thin Life
# ...           ...                                                ...
# 146134  tt9916160                                         Drømmeland
# 146135  tt9916170                                      The Rehearsal
# 146136  tt9916186  Illenau - die Geschichte einer ehemaligen Heil...
# 146137  tt9916190                                          Safeguard
# 146139  tt9916538                                Kuambil Lagi Hatiku
#
#                                            original_title  start_year  \
# ...

# %%
new_title_ratings = title_ratings.loc[title_ratings['numvotes'] > 1000]
new_title_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9611 entries, 3 to 73831
# Data columns (total 3 columns):
# tconst           9611 non-null object
# averagerating    9611 non-null float64
# numvotes         9611 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 300.3+ KB

# %%
title_ratings
# Out:
#            tconst  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
tmdb.str.contains(2, regex=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-109-21c83d542d8d> in <module>
# ----> 1 tmdb.str.contains(2, regex=False)
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
tmdb
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# ...

# %%
movie_budgets
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...
